# %% [markdown]
# **Applying Advanced Transformations**

# %% [markdown]
# I. Clean the files and combine them into one final DataFrame.
# This dataframe should have the following columns:
# Hero (Just the name of the Hero)
# Publisher
# Gender
# Eye color
# Race
# Hair color
# Height (numeric)
# Skin color
# Alignment
# Weight (numeric)
# Plus, one-hot-encoded columns for every power that appears in the dataset. E.g.: Agility * Flight * Superspeed etc. Hint: There is a space in "100 kg" or "52.5 cm"
#
# II. Use your combined DataFrame to answer the following questions.
# Compare the average weight of super powers who have Super Speed to those who do not.
# What is the average height of heroes for each publisher?

# %%
#Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os,json

# %%
#Upload the Data
df_superinfo = pd.read_csv('Data/superhero_info - superhero_info.csv')
df_superpowers = pd.read_csv('Data/superhero_powers - superhero_powers.csv')

df_superinfo.head()
# Out:
#                  Hero|Publisher Gender               Race Alignment  \
# 0          A-Bomb|Marvel Comics   Male              Human      good
# 1  Abe Sapien|Dark Horse Comics   Male      Icthyo Sapien      good
# 2            Abin Sur|DC Comics   Male            Ungaran      good
# 3     Abomination|Marvel Comics   Male  Human / Radiation       bad
# 4   Absorbing Man|Marvel Comics   Male              Human       bad
#
#   Hair color Eye color Skin color  \
# 0    No Hair    yellow    Unknown
# 1    No Hair      blue       blue
# 2    No Hair      blue        red
# 3    No Hair     green    Unknown
# 4    No Hair      blue    Unknown
#
#                                    Measurements
# 0  {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 1   {'Height': '191.0 cm', 'Weight': '65.0 kg'}
# 2   {'Height': '185.0 cm', 'Weight': '90.0 kg'}
# 3  {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 4  {'Height': '193.0 cm', 'Weight': '122.0 kg'}

# %%
df_superpowers.head()
# Out:
#     hero_names                                             Powers
# 0      3-D Man         Agility,Super Strength,Stamina,Super Speed
# 1       A-Bomb  Accelerated Healing,Durability,Longevity,Super...
# 2   Abe Sapien  Agility,Accelerated Healing,Cold Resistance,Du...
# 3     Abin Sur                                 Lantern Power Ring
# 4  Abomination  Accelerated Healing,Intelligence,Super Strengt...

# %% [markdown]
# **Separate the Hero Names from the Publisher.**

# %%
#Split Hero and Publisher
df_superinfo[['Hero', 'Publisher']] = df_superinfo['Hero|Publisher'].str.split('|', expand=True)

# %%
#Check that the split was performed successfully and correctly 
df_superinfo.head()
# Out:
#                  Hero|Publisher Gender               Race Alignment  \
# 0          A-Bomb|Marvel Comics   Male              Human      good
# 1  Abe Sapien|Dark Horse Comics   Male      Icthyo Sapien      good
# 2            Abin Sur|DC Comics   Male            Ungaran      good
# 3     Abomination|Marvel Comics   Male  Human / Radiation       bad
# 4   Absorbing Man|Marvel Comics   Male              Human       bad
#
#   Hair color Eye color Skin color  \
# 0    No Hair    yellow    Unknown
# 1    No Hair      blue       blue
# 2    No Hair      blue        red
# 3    No Hair     green    Unknown
# 4    No Hair      blue    Unknown
#
#                                    Measurements           Hero  \
# 0  {'Height': '203.0 cm', 'Weight': '441.0 kg'}         A-Bomb
# 1   {'Height': '191.0 cm', 'Weight': '65.0 kg'}     Abe Sapien
# 2   {'Height': '185.0 cm', 'Weight': '90.0 kg'}       Abin Sur
# 3  {'Height': '203.0 cm', 'Weight': '441.0 kg'}    Abomination
# 4  {'Height': '193.0 cm', 'Weight': '122.0 kg'}  Absorbing Man
#
#            Publisher
# 0      Marvel Comics
# 1  Dark Horse Comics
# 2          DC Comics
# 3      Marvel Comics
# 4      Marvel Comics

# %%
#Drop the Hero|Publisher column 
df_superinfo.drop(columns= 'Hero|Publisher', inplace=True)

# %%
#Check that the Hero|Publisher column  was dropped successfully and correctly
df_superinfo.head()
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
#
#                                    Measurements           Hero  \
# 0  {'Height': '203.0 cm', 'Weight': '441.0 kg'}         A-Bomb
# 1   {'Height': '191.0 cm', 'Weight': '65.0 kg'}     Abe Sapien
# 2   {'Height': '185.0 cm', 'Weight': '90.0 kg'}       Abin Sur
# 3  {'Height': '203.0 cm', 'Weight': '441.0 kg'}    Abomination
# 4  {'Height': '193.0 cm', 'Weight': '122.0 kg'}  Absorbing Man
#
#            Publisher
# 0      Marvel Comics
# 1  Dark Horse Comics
# 2          DC Comics
# 3      Marvel Comics
# 4      Marvel Comics

# %% [markdown]
# **Separating the Measurements into a dictionary with the Height being the Key for each weight for each Super Hero.**

# %%
#Let's change the Measurements column to a dictionary
df_superinfo['Measurements'] = df_superinfo['Measurements'].str.replace("'",'"')
df_superinfo['Measurements'] = df_superinfo['Measurements'].apply(json.loads)

# %%
#Verify or check it worked
check = df_superinfo.loc[0, 'Measurements']
df_superinfo.head()
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
#
#                                    Measurements           Hero  \
# 0  {'Height': '203.0 cm', 'Weight': '441.0 kg'}         A-Bomb
# 1   {'Height': '191.0 cm', 'Weight': '65.0 kg'}     Abe Sapien
# 2   {'Height': '185.0 cm', 'Weight': '90.0 kg'}       Abin Sur
# 3  {'Height': '203.0 cm', 'Weight': '441.0 kg'}    Abomination
# 4  {'Height': '193.0 cm', 'Weight': '122.0 kg'}  Absorbing Man
#
#            Publisher
# 0      Marvel Comics
# 1  Dark Horse Comics
# 2          DC Comics
# 3      Marvel Comics
# 4      Marvel Comics

# %%
check = df_superinfo['Measurements'].apply(pd.Series)

# %%
#Add new columns for Measurments 
df_superinfo  = pd.concat((df_superinfo, check), axis=1)

# %%
#Check that new columns were added succesfully 
df_superinfo.head()
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
#
#                                    Measurements           Hero  \
# 0  {'Height': '203.0 cm', 'Weight': '441.0 kg'}         A-Bomb
# 1   {'Height': '191.0 cm', 'Weight': '65.0 kg'}     Abe Sapien
# 2   {'Height': '185.0 cm', 'Weight': '90.0 kg'}       Abin Sur
# 3  {'Height': '203.0 cm', 'Weight': '441.0 kg'}    Abomination
# 4  {'Height': '193.0 cm', 'Weight': '122.0 kg'}  Absorbing Man
#
#            Publisher    Height    Weight
# 0      Marvel Comics  203.0 cm  441.0 kg
# 1  Dark Horse Comics  191.0 cm   65.0 kg
# 2          DC Comics  185.0 cm   90.0 kg
# 3      Marvel Comics  203.0 cm  441.0 kg
# 4      Marvel Comics  193.0 cm  122.0 kg

# %%
#Drop the Measurements column 
df_superinfo.drop(columns = ['Measurements'], inplace=True)

# %%
df_superinfo.head()
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
#
#             Hero          Publisher    Height    Weight
# 0         A-Bomb      Marvel Comics  203.0 cm  441.0 kg
# 1     Abe Sapien  Dark Horse Comics  191.0 cm   65.0 kg
# 2       Abin Sur          DC Comics  185.0 cm   90.0 kg
# 3    Abomination      Marvel Comics  203.0 cm  441.0 kg
# 4  Absorbing Man      Marvel Comics  193.0 cm  122.0 kg

# %%
df_superinfo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 463 entries, 0 to 462
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Gender      463 non-null    object
#  1   Race        463 non-null    object
#  2   Alignment   463 non-null    object
#  3   Hair color  463 non-null    object
#  4   Eye color   463 non-null    object
#  5   Skin color  463 non-null    object
#  6   Hero        463 non-null    object
#  7   Publisher   463 non-null    object
#  8   Height      463 non-null    object
#  9   Weight      463 non-null    object
# dtypes: object(10)
# memory usage: 36.3+ KB

# %%
#Convert the Height and Weight columns into string data types then I can convert to them to float 
df_superinfo['Height'] = df_superinfo['Height'].astype('string')
df_superinfo['Weight'] = df_superinfo['Weight'].astype('string')

# %%
df_superinfo['Height'] = df_superinfo['Height'].apply(lambda x: x.split(' ')[0])
df_superinfo['Weight'] = df_superinfo['Weight'].apply(lambda x: x.split(' ')[0])

# %%
#Convert the Height and Weight columns into float data types 
df_superinfo['Height'] = df_superinfo['Height'].astype(float)
df_superinfo['Weight'] = df_superinfo['Weight'].astype(float)

# %%
df_superinfo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 463 entries, 0 to 462
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Gender      463 non-null    object
#  1   Race        463 non-null    object
#  2   Alignment   463 non-null    object
#  3   Hair color  463 non-null    object
#  4   Eye color   463 non-null    object
#  5   Skin color  463 non-null    object
#  6   Hero        463 non-null    object
#  7   Publisher   463 non-null    object
#  8   Height      463 non-null    float64
#  9   Weight      463 non-null    float64
# dtypes: float64(2), object(8)
# memory usage: 36.3+ KB

# %%
df_superinfo.head()
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
#
#             Hero          Publisher  Height  Weight
# 0         A-Bomb      Marvel Comics   203.0   441.0
# 1     Abe Sapien  Dark Horse Comics   191.0    65.0
# 2       Abin Sur          DC Comics   185.0    90.0
# 3    Abomination      Marvel Comics   203.0   441.0
# 4  Absorbing Man      Marvel Comics   193.0   122.0

# %% [markdown]
# **Done!**

# %%
df_superpowers.head()
# Out:
#     hero_names                                             Powers
# 0      3-D Man         Agility,Super Strength,Stamina,Super Speed
# 1       A-Bomb  Accelerated Healing,Durability,Longevity,Super...
# 2   Abe Sapien  Agility,Accelerated Healing,Cold Resistance,Du...
# 3     Abin Sur                                 Lantern Power Ring
# 4  Abomination  Accelerated Healing,Intelligence,Super Strengt...

# %% [markdown]
# **Must split the individual superpowers in the Powers table.**

# %%
df_superpowers['Powers_Split'] = df_superpowers['Powers'].str.split(',', expand=False)
df_superpowers.head()
# Out:
#     hero_names                                             Powers  \
# 0      3-D Man         Agility,Super Strength,Stamina,Super Speed
# 1       A-Bomb  Accelerated Healing,Durability,Longevity,Super...
# 2   Abe Sapien  Agility,Accelerated Healing,Cold Resistance,Du...
# 3     Abin Sur                                 Lantern Power Ring
# 4  Abomination  Accelerated Healing,Intelligence,Super Strengt...
#
#                                         Powers_Split
# 0    [Agility, Super Strength, Stamina, Super Speed]
# 1  [Accelerated Healing, Durability, Longevity, S...
# 2  [Agility, Accelerated Healing, Cold Resistance...
# 3                               [Lantern Power Ring]
# 4  [Accelerated Healing, Intelligence, Super Stre...

# %%
#Explode
exploade = df_superpowers.explode('Powers_Split')

# %%
cols = exploade['Powers_Split'].dropna().unique()

# %%
for col in cols:    
    df_superpowers[col] = df_superpowers['Powers'].str.contains(col) 

#Check that the Powers were converted to Columns 
df_superpowers.head()
# Out:
# /var/folders/x9/3qks5g991w745rj9dzrqqy200000gn/T/ipykernel_18378/1090971143.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_superpowers[col] = df_superpowers['Powers'].str.contains(col)
# /var/folders/x9/3qks5g991w745rj9dzrqqy200000gn/T/ipykernel_18378/1090971143.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_superpowers[col] = df_superpowers['Powers'].str.contains(col)
# /var/folders/x9/3qks5g991w745rj9dzrqqy200000gn/T/ipykernel_18378/1090971143.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_superpowers[col] = df_superpowers['Powers'].str.contains(col)
# /var/folders/x9/3qks5g991w745rj9dzrqqy200000gn/T/ipykernel_18378/1090971143.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_superpowers[col] = df_superpowers['Powers'].str.contains(col)
# /var/folders/x9/3qks5g991w745rj9dzrqqy200000gn/T/ipykernel_18378/1090971143.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_superpowers[col] = df_superpowers['Powers'].str.contains(col)
# /var/folders/x9/3qks5g991w745rj9dzrqqy200000gn/T/ipykernel_18378/1090971143.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_superpowers[col] = df_superpowers['Powers'].str.contains(col)
# /var/folders/x9/3qks5g991w745rj9dzrqqy200000gn/T/ipykernel_18378/1090971143.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_superpowers[col] = df_superpowers['Powers'].str.contains(col)
# /var/folders/x9/3qks5g991w745rj9dzrqqy200000gn/T/ipykernel_18378/1090971143.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_superpowers[col] = df_superpowers['Powers'].str.contains(col)
# /var/folders/x9/3qks5g991w745rj9dzrqqy200000gn/T/ipykernel_18378/1090971143.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_superpowers[col] = df_superpowers['Powers'].str.contains(col)
# /var/folders/x9/3qks5g991w745rj9dzrqqy200000gn/T/ipykernel_18378/1090971143.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_superpowers[col] = df_superpowers['Powers'].str.contains(col)
# /var/folders/x9/3qks5g991w745rj9dzrqqy200000gn/T/ipykernel_18378/1090971143.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_superpowers[col] = df_superpowers['Powers'].str.contains(col)
# /var/folders/x9/3qks5g991w745rj9dzrqqy200000gn/T/ipykernel_18378/1090971143.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_superpowers[col] = df_superpowers['Powers'].str.contains(col)
# /var/folders/x9/3qks5g991w745rj9dzrqqy200000gn/T/ipykernel_18378/1090971143.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_superpowers[col] = df_superpowers['Powers'].str.contains(col)
# /var/folders/x9/3qks5g991w745rj9dzrqqy200000gn/T/ipykernel_18378/1090971143.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_superpowers[col] = df_superpowers['Powers'].str.contains(col)
# /var/folders/x9/3qks5g991w745rj9dzrqqy200000gn/T/ipykernel_18378/1090971143.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_superpowers[col] = df_superpowers['Powers'].str.contains(col)
# /var/folders/x9/3qks5g991w745rj9dzrqqy200000gn/T/ipykernel_18378/1090971143.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_superpowers[col] = df_superpowers['Powers'].str.contains(col)
# /var/folders/x9/3qks5g991w745rj9dzrqqy200000gn/T/ipykernel_18378/1090971143.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_superpowers[col] = df_superpowers['Powers'].str.contains(col)
# /var/folders/x9/3qks5g991w745rj9dzrqqy200000gn/T/ipykernel_18378/1090971143.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_superpowers[col] = df_superpowers['Powers'].str.contains(col)
# /var/folders/x9/3qks5g991w745rj9dzrqqy200000gn/T/ipykernel_18378/1090971143.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_superpowers[col] = df_superpowers['Powers'].str.contains(col)
# /var/folders/x9/3qks5g991w745rj9dzrqqy200000gn/T/ipykernel_18378/1090971143.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_superpowers[col] = df_superpowers['Powers'].str.contains(col)
# /var/folders/x9/3qks5g991w745rj9dzrqqy200000gn/T/ipykernel_18378/1090971143.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_superpowers[col] = df_superpowers['Powers'].str.contains(col)
# /var/folders/x9/3qks5g991w745rj9dzrqqy200000gn/T/ipykernel_18378/1090971143.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_superpowers[col] = df_superpowers['Powers'].str.contains(col)
# /var/folders/x9/3qks5g991w745rj9dzrqqy200000gn/T/ipykernel_18378/1090971143.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_superpowers[col] = df_superpowers['Powers'].str.contains(col)
# /var/folders/x9/3qks5g991w745rj9dzrqqy200000gn/T/ipykernel_18378/1090971143.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_superpowers[col] = df_superpowers['Powers'].str.contains(col)
# /var/folders/x9/3qks5g991w745rj9dzrqqy200000gn/T/ipykernel_18378/1090971143.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_superpowers[col] = df_superpowers['Powers'].str.contains(col)
# /var/folders/x9/3qks5g991w745rj9dzrqqy200000gn/T/ipykernel_18378/1090971143.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_superpowers[col] = df_superpowers['Powers'].str.contains(col)
# /var/folders/x9/3qks5g991w745rj9dzrqqy200000gn/T/ipykernel_18378/1090971143.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_superpowers[col] = df_superpowers['Powers'].str.contains(col)
# /var/folders/x9/3qks5g991w745rj9dzrqqy200000gn/T/ipykernel_18378/1090971143.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_superpowers[col] = df_superpowers['Powers'].str.contains(col)
# /var/folders/x9/3qks5g991w745rj9dzrqqy200000gn/T/ipykernel_18378/1090971143.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_superpowers[col] = df_superpowers['Powers'].str.contains(col)
# /var/folders/x9/3qks5g991w745rj9dzrqqy200000gn/T/ipykernel_18378/1090971143.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_superpowers[col] = df_superpowers['Powers'].str.contains(col)
# /var/folders/x9/3qks5g991w745rj9dzrqqy200000gn/T/ipykernel_18378/1090971143.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_superpowers[col] = df_superpowers['Powers'].str.contains(col)
# /var/folders/x9/3qks5g991w745rj9dzrqqy200000gn/T/ipykernel_18378/1090971143.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_superpowers[col] = df_superpowers['Powers'].str.contains(col)
# /var/folders/x9/3qks5g991w745rj9dzrqqy200000gn/T/ipykernel_18378/1090971143.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_superpowers[col] = df_superpowers['Powers'].str.contains(col)
# /var/folders/x9/3qks5g991w745rj9dzrqqy200000gn/T/ipykernel_18378/1090971143.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_superpowers[col] = df_superpowers['Powers'].str.contains(col)
# /var/folders/x9/3qks5g991w745rj9dzrqqy200000gn/T/ipykernel_18378/1090971143.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_superpowers[col] = df_superpowers['Powers'].str.contains(col)
# /var/folders/x9/3qks5g991w745rj9dzrqqy200000gn/T/ipykernel_18378/1090971143.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_superpowers[col] = df_superpowers['Powers'].str.contains(col)
# /var/folders/x9/3qks5g991w745rj9dzrqqy200000gn/T/ipykernel_18378/1090971143.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_superpowers[col] = df_superpowers['Powers'].str.contains(col)
# /var/folders/x9/3qks5g991w745rj9dzrqqy200000gn/T/ipykernel_18378/1090971143.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_superpowers[col] = df_superpowers['Powers'].str.contains(col)
# /var/folders/x9/3qks5g991w745rj9dzrqqy200000gn/T/ipykernel_18378/1090971143.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_superpowers[col] = df_superpowers['Powers'].str.contains(col)
# /var/folders/x9/3qks5g991w745rj9dzrqqy200000gn/T/ipykernel_18378/1090971143.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_superpowers[col] = df_superpowers['Powers'].str.contains(col)
# /var/folders/x9/3qks5g991w745rj9dzrqqy200000gn/T/ipykernel_18378/1090971143.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_superpowers[col] = df_superpowers['Powers'].str.contains(col)
# /var/folders/x9/3qks5g991w745rj9dzrqqy200000gn/T/ipykernel_18378/1090971143.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_superpowers[col] = df_superpowers['Powers'].str.contains(col)
# /var/folders/x9/3qks5g991w745rj9dzrqqy200000gn/T/ipykernel_18378/1090971143.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_superpowers[col] = df_superpowers['Powers'].str.contains(col)
# /var/folders/x9/3qks5g991w745rj9dzrqqy200000gn/T/ipykernel_18378/1090971143.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_superpowers[col] = df_superpowers['Powers'].str.contains(col)
# /var/folders/x9/3qks5g991w745rj9dzrqqy200000gn/T/ipykernel_18378/1090971143.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_superpowers[col] = df_superpowers['Powers'].str.contains(col)
# /var/folders/x9/3qks5g991w745rj9dzrqqy200000gn/T/ipykernel_18378/1090971143.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_superpowers[col] = df_superpowers['Powers'].str.contains(col)
# /var/folders/x9/3qks5g991w745rj9dzrqqy200000gn/T/ipykernel_18378/1090971143.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_superpowers[col] = df_superpowers['Powers'].str.contains(col)
# /var/folders/x9/3qks5g991w745rj9dzrqqy200000gn/T/ipykernel_18378/1090971143.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_superpowers[col] = df_superpowers['Powers'].str.contains(col)
# /var/folders/x9/3qks5g991w745rj9dzrqqy200000gn/T/ipykernel_18378/1090971143.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_superpowers[col] = df_superpowers['Powers'].str.contains(col)
# /var/folders/x9/3qks5g991w745rj9dzrqqy200000gn/T/ipykernel_18378/1090971143.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_superpowers[col] = df_superpowers['Powers'].str.contains(col)
# /var/folders/x9/3qks5g991w745rj9dzrqqy200000gn/T/ipykernel_18378/1090971143.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_superpowers[col] = df_superpowers['Powers'].str.contains(col)
# /var/folders/x9/3qks5g991w745rj9dzrqqy200000gn/T/ipykernel_18378/1090971143.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_superpowers[col] = df_superpowers['Powers'].str.contains(col)
# /var/folders/x9/3qks5g991w745rj9dzrqqy200000gn/T/ipykernel_18378/1090971143.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_superpowers[col] = df_superpowers['Powers'].str.contains(col)
# /var/folders/x9/3qks5g991w745rj9dzrqqy200000gn/T/ipykernel_18378/1090971143.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_superpowers[col] = df_superpowers['Powers'].str.contains(col)
# /var/folders/x9/3qks5g991w745rj9dzrqqy200000gn/T/ipykernel_18378/1090971143.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_superpowers[col] = df_superpowers['Powers'].str.contains(col)
# /var/folders/x9/3qks5g991w745rj9dzrqqy200000gn/T/ipykernel_18378/1090971143.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_superpowers[col] = df_superpowers['Powers'].str.contains(col)
# /var/folders/x9/3qks5g991w745rj9dzrqqy200000gn/T/ipykernel_18378/1090971143.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_superpowers[col] = df_superpowers['Powers'].str.contains(col)
# /var/folders/x9/3qks5g991w745rj9dzrqqy200000gn/T/ipykernel_18378/1090971143.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_superpowers[col] = df_superpowers['Powers'].str.contains(col)
# /var/folders/x9/3qks5g991w745rj9dzrqqy200000gn/T/ipykernel_18378/1090971143.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_superpowers[col] = df_superpowers['Powers'].str.contains(col)
# /var/folders/x9/3qks5g991w745rj9dzrqqy200000gn/T/ipykernel_18378/1090971143.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_superpowers[col] = df_superpowers['Powers'].str.contains(col)
# /var/folders/x9/3qks5g991w745rj9dzrqqy200000gn/T/ipykernel_18378/1090971143.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_superpowers[col] = df_superpowers['Powers'].str.contains(col)
# /var/folders/x9/3qks5g991w745rj9dzrqqy200000gn/T/ipykernel_18378/1090971143.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_superpowers[col] = df_superpowers['Powers'].str.contains(col)
# /var/folders/x9/3qks5g991w745rj9dzrqqy200000gn/T/ipykernel_18378/1090971143.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_superpowers[col] = df_superpowers['Powers'].str.contains(col)
# /var/folders/x9/3qks5g991w745rj9dzrqqy200000gn/T/ipykernel_18378/1090971143.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_superpowers[col] = df_superpowers['Powers'].str.contains(col)
# /var/folders/x9/3qks5g991w745rj9dzrqqy200000gn/T/ipykernel_18378/1090971143.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_superpowers[col] = df_superpowers['Powers'].str.contains(col)
# /var/folders/x9/3qks5g991w745rj9dzrqqy200000gn/T/ipykernel_18378/1090971143.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_superpowers[col] = df_superpowers['Powers'].str.contains(col)
# /var/folders/x9/3qks5g991w745rj9dzrqqy200000gn/T/ipykernel_18378/1090971143.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_superpowers[col] = df_superpowers['Powers'].str.contains(col)
# /var/folders/x9/3qks5g991w745rj9dzrqqy200000gn/T/ipykernel_18378/1090971143.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_superpowers[col] = df_superpowers['Powers'].str.contains(col)
# /var/folders/x9/3qks5g991w745rj9dzrqqy200000gn/T/ipykernel_18378/1090971143.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_superpowers[col] = df_superpowers['Powers'].str.contains(col)
#     hero_names                                             Powers  \
# 0      3-D Man         Agility,Super Strength,Stamina,Super Speed
# 1       A-Bomb  Accelerated Healing,Durability,Longevity,Super...
# 2   Abe Sapien  Agility,Accelerated Healing,Cold Resistance,Du...
# 3     Abin Sur                                 Lantern Power Ring
# 4  Abomination  Accelerated Healing,Intelligence,Super Strengt...
#
#                                         Powers_Split  Agility  Super Strength  \
# 0    [Agility, Super Strength, Stamina, Super Speed]     True            True
# 1  [Accelerated Healing, Durability, Longevity, S...    False            True
# 2  [Agility, Accelerated Healing, Cold Resistance...     True            True
# 3                               [Lantern Power Ring]    False           False
# 4  [Accelerated Healing, Intelligence, Super Stre...    False            True
#
#    Stamina  Super Speed  Accelerated Healing  Durability  Longevity  ...  \
# 0     True         True                False       False      False  ...
# 1     True        False                 True        True       True  ...
# 2     True        False                 True        True       True  ...
# 3    False        False                False       False      False  ...
# 4     True         True                 True       False      False  ...
#
#    Weather Control  Omnipresent  Omniscient  Hair Manipulation  Nova Force  \
# 0            False        False       False              False       False
# 1            False        False       False              False       False
# 2            False        False       False              False       False
# 3            False        False       False              False       False
# 4            False        False       False              False       False
#
#    Odin Force  Phoenix Force  Intuitive aptitude  Melting  Changing Armor
# 0       False          False               False    False           False
# 1       False          False               False    False           False
# 2       False          False               False    False           False
# 3       False          False               False    False           False
# 4       False          False               False    False           False
#
# [5 rows x 170 columns]

# %%
#Merge the Two Tables 
merged_tables = pd.merge(df_superinfo, df_superpowers, left_on='Hero', right_on='hero_names', how='inner')
merged_tables.head(40)
# Out:
#     Gender               Race Alignment Hair color Eye color Skin color  \
# 0     Male              Human      good    No Hair    yellow    Unknown
# 1     Male      Icthyo Sapien      good    No Hair      blue       blue
# 2     Male            Ungaran      good    No Hair      blue        red
# 3     Male  Human / Radiation       bad    No Hair     green    Unknown
# 4     Male              Human       bad    No Hair      blue    Unknown
# 5     Male              Human      good      Blond      blue    Unknown
# 6     Male              Human      good      Brown     brown    Unknown
# 7     Male            Unknown      good    Unknown   Unknown    Unknown
# 8     Male            Unknown       bad      White      blue    Unknown
# 9     Male             Cyborg       bad      Black     brown    Unknown
# 10    Male            Unknown      good      Blond      blue    Unknown
# 11    Male    Xenomorph XX121       bad    No Hair   Unknown      black
# 12    Male            Android       bad    Unknown       red    Unknown
# 13    Male              Human       bad      Black     brown    Unknown
# 14    Male            Unknown      good      Blond      blue    Unknown
# 15  Female             Mutant      good      Black    yellow    Unknown
# 16  Female            Unknown      good      Black     brown    Unknown
# 17    Male              Human      good      Blond      blue    Unknown
# 18    Male            Unknown       bad    No Hair     green    Unknown
# 19    Male              Human      good      Blond      blue    Unknown
# 20    Male              Human      good      Blond      blue    Unknown
# 21    Male           Symbiote   Unknown      Blond      blue    Unknown
# 22    Male             Mutant       bad      Black       red       grey
# 23    Male          Atlantean      good      Black      blue    Unknown
# 24    Male          Atlantean      good      Blond      blue    Unknown
# 25  Female              Human      good      Blond      blue    Unknown
# 26    Male             Mutant      good      Blond      blue       blue
# 27  Female            Unknown       bad     Purple    violet    Unknown
# 28  Female              Alien      good     Orange     white       gold
# 29    Male            Unknown      good      Brown     brown    Unknown
# 30  Female            Unknown      good       Pink    purple    Unknown
# 31  Female            Unknown      good      Black     black    Unknown
# 32    Male             Mutant      good        Red     brown    Unknown
# 33    Male      God / Eternal       bad      Brown      blue    Unknown
# 34    Male            Unknown      good        Red      blue    Unknown
# 35  Female            Unknown      good      Black     black    Unknown
# 36    Male              Human      good     Auburn     brown    Unknown
# 37  Female             Mutant      good      Black      blue    Unknown
# 38    Male           Neyaphem       bad      Black    yellow        red
# 39    Male              Human       bad    Unknown   Unknown    Unknown
#
#                Hero          Publisher  Height  Weight  ... Weather Control  \
# 0            A-Bomb      Marvel Comics   203.0   441.0  ...           False
# 1        Abe Sapien  Dark Horse Comics   191.0    65.0  ...           False
# 2          Abin Sur          DC Comics   185.0    90.0  ...           False
# 3       Abomination      Marvel Comics   203.0   441.0  ...           False
# 4     Absorbing Man      Marvel Comics   193.0   122.0  ...           False
# 5      Adam Strange          DC Comics   185.0    88.0  ...           False
# 6         Agent Bob      Marvel Comics   178.0    81.0  ...           False
# 7        Agent Zero      Marvel Comics   191.0   104.0  ...           False
# 8        Air-Walker      Marvel Comics   188.0   108.0  ...           False
# 9              Ajax      Marvel Comics   193.0    90.0  ...           False
# 10       Alan Scott          DC Comics   180.0    90.0  ...           False
# 11            Alien  Dark Horse Comics   244.0   169.0  ...           False
# 12            Amazo          DC Comics   257.0   173.0  ...           False
# 13             Ammo      Marvel Comics   188.0   101.0  ...           False
# 14            Angel      Marvel Comics   183.0    68.0  ...           False
# 15       Angel Dust      Marvel Comics   165.0    57.0  ...           False
# 16  Angel Salvadore      Marvel Comics   163.0    54.0  ...           False
# 17       Animal Man          DC Comics   183.0    83.0  ...           False
# 18        Annihilus      Marvel Comics   180.0    90.0  ...           False
# 19          Ant-Man      Marvel Comics   211.0   122.0  ...           False
# 20       Ant-Man II      Marvel Comics   183.0    86.0  ...           False
# 21       Anti-Venom      Marvel Comics   229.0   358.0  ...           False
# 22       Apocalypse      Marvel Comics   213.0   135.0  ...           False
# 23          Aqualad          DC Comics   178.0   106.0  ...           False
# 24          Aquaman          DC Comics   185.0   146.0  ...           False
# 25          Arachne      Marvel Comics   175.0    63.0  ...           False
# 26        Archangel      Marvel Comics   183.0    68.0  ...           False
# 27         Arclight      Marvel Comics   173.0    57.0  ...           False
# 28           Ardina      Marvel Comics   193.0    98.0  ...           False
# 29             Ares      Marvel Comics   185.0   270.0  ...           False
# 30            Ariel      Marvel Comics   165.0    59.0  ...           False
# 31            Armor      Marvel Comics   163.0    50.0  ...           False
# 32            Atlas      Marvel Comics   183.0   101.0  ...           False
# 33            Atlas          DC Comics   198.0   126.0  ...           False
# 34             Atom          DC Comics   178.0    68.0  ...           False
# 35        Atom Girl          DC Comics   168.0    54.0  ...           False
# 36          Atom II          DC Comics   183.0    81.0  ...           False
# 37           Aurora      Marvel Comics   180.0    63.0  ...           False
# 38           Azazel      Marvel Comics   183.0    67.0  ...           False
# 39             Bane          DC Comics   203.0   180.0  ...           False
#
#    Omnipresent Omniscient  Hair Manipulation  Nova Force  Odin Force  \
# 0        False      False              False       False       False
# 1        False      False              False       False       False
# 2        False      False              False       False       False
# 3        False      False              False       False       False
# 4        False      False              False       False       False
# 5        False      False              False       False       False
# 6        False      False              False       False       False
# 7        False      False              False       False       False
# 8        False      False              False       False       False
# 9        False      False              False       False       False
# 10       False      False              False       False       False
# 11       False      False              False       False       False
# 12       False      False              False       False       False
# 13       False      False              False       False       False
# 14       False      False              False       False       False
# 15       False      False              False       False       False
# 16       False      False              False       False       False
# 17       False      False              False       False       False
# 18       False      False              False       False       False
# 19       False      False              False       False       False
# 20       False      False              False       False       False
# 21       False      False              False       False       False
# 22       False      False              False       False       False
# 23       False      False              False       False       False
# 24       False      False              False       False       False
# 25       False      False              False       False       False
# 26       False      False              False       False       False
# 27       False      False              False       False       False
# 28       False      False              False       False       False
# 29       False      False              False       False       False
# 30       False      False              False       False       False
# 31       False      False              False       False       False
# 32       False      False              False       False       False
# 33       False      False              False       False       False
# 34       False      False              False       False       False
# 35       False      False              False       False       False
# 36       False      False              False       False       False
# 37       False      False              False       False       False
# 38       False      False              False       False       False
# 39       False      False              False       False       False
#
#     Phoenix Force  Intuitive aptitude  Melting  Changing Armor
# 0           False               False    False           False
# 1           False               False    False           False
# 2           False               False    False           False
# 3           False               False    False           False
# 4           False               False    False           False
# 5           False               False    False           False
# 6           False               False    False           False
# 7           False               False    False           False
# 8           False               False    False           False
# 9           False               False    False           False
# 10          False               False    False           False
# 11          False               False    False           False
# 12          False               False    False           False
# 13          False               False    False           False
# 14          False               False    False           False
# 15          False               False    False           False
# 16          False               False    False           False
# 17          False               False    False           False
# 18          False               False    False           False
# 19          False               False    False           False
# 20          False               False    False           False
# 21          False               False    False           False
# 22          False               False    False           False
# 23          False               False    False           False
# 24          False               False    False           False
# 25          False               False    False           False
# 26          False               False    False           False
# 27          False               False    False           False
# 28          False               False    False           False
# 29          False               False    False           False
# 30          False               False    False           False
# 31          False               False    False           False
# 32          False               False    False           False
# 33          False               False    False           False
# 34          False               False    False           False
# 35          False               False    False           False
# 36          False               False    False           False
# 37          False               False    False           False
# 38          False               False    False           False
# 39          False               False    False           False
#
# [40 rows x 180 columns]

# %% [markdown]
# **Using my Data Frame to answer the required questions.**

# %%
#Compare the average weight of super powers who have Super Speed to those who do not.
superspeed = merged_tables['Super Speed'] == True 

speed_df = merged_tables[superspeed]
slow_df = merged_tables[~superspeed]

print (f'Average weight for heroes who have Super Speed is:',speed_df['Weight'].mean())
print (f"Average weight for heroeswho don't have Super Sped is :", slow_df['Weight'].mean())
# Out:
# Average weight for heroes who have Super Speed is: 129.40404040404042
# Average weight for heroeswho don't have Super Sped is : 101.77358490566037

# %%
#What is the average height of heroes for each publisher?
merged_tables.groupby('Publisher')['Height'].mean()
# Out:
# Publisher
# DC Comics            181.923913
# Dark Horse Comics    176.909091
# George Lucas         159.600000
# Image Comics         211.000000
# Marvel Comics        191.546128
# Shueisha             171.500000
# Star Trek            181.500000
# Team Epic TV         180.750000
# Unknown              178.000000
# Name: Height, dtype: float64

# %% [markdown]
# **Done!**
